# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/BD-DM-C02/blob/main/ws2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/refs/heads/main/dataset/cereal.csv')
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data = pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/refs/heads/main/dataset/cereal.csv')

# %%
data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %%
data.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
data.tail(18)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 59            Raisin Nut Bran   G    C       100        3    2     140    2.5
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 61                  Rice Chex   R    C       110        1    0     240    0.0
# 62              Rice Krispies   K    C       110        2    0     290    0.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 66                     Smacks   K    C       110        2    1      70    1.0
# 67                  Special K   K    C       110        6    0     230    1.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69          Total Corn Flakes   G    C       110        2    1     200    0.0
# ...

# %%
data.sample(13)
# Out:
#                                 name mfr type  calories  protein  fat  sodium  \
# 44  Muesli Raisins; Dates; & Almonds   R    C       150        4    3      95
# 24                       Froot Loops   K    C       110        2    1     125
# 65         Shredded Wheat spoon size   N    C        90        3    0       0
# 14                       Cocoa Puffs   G    C       110        1    1     180
# 18                     Count Chocula   G    C       110        1    1     180
# 56                Quaker Oat Squares   Q    C       100        4    1     135
# 55                      Puffed Wheat   Q    C        50        2    0       0
# 54                       Puffed Rice   Q    C        50        1    0       0
# 30                      Golden Crisp   P    C       100        2    0      45
# 5            Apple Cinnamon Cheerios   G    C       110        2    2     180
# 60                    Raisin Squares   K    C        90        2    0       0
# ...

# %%
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass      shelf     weight       cups     rating
# count  76.000000   75.000000  77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   2.207792   1.029610   0.821039  42.665705
# std     4.378656   70.410636   0.832524   0.150477   0.232716  14.047289
# ...

# %%
data[data.mfr=='K']
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 16                  Corn Flakes   K    C       100        2    0     290
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 25               Frosted Flakes   K    C       110        1    0     200
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# 28                Fruitful Bran   K    C       120        3    0     240
# 38  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# ...

# %%
data[data.fat>=2]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100% Natural Bran   Q    C       120        3    5
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 7                                  Basic 4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# 19                      Cracklin' Oat Bran   K    C       110        3    3
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 34                      Great Grains Pecan   P    C       120        3    3
# ...

# %%
data.name
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
data[['name','mfr','rating']]
# Out:
#                          name mfr     rating
# 0                   100% Bran   N  68.402973
# 1           100% Natural Bran   Q  33.983679
# 2                    All-Bran   K  59.425505
# 3   All-Bran with Extra Fiber   K  93.704912
# 4              Almond Delight   R  34.384843
# ..                        ...  ..        ...
# 72                    Triples   G  39.106174
# 73                       Trix   G  27.753301
# 74                 Wheat Chex   R  49.787445
# 75                   Wheaties   G  51.592193
# 76        Wheaties Honey Gold   G  36.187559
#
# [77 rows x 3 columns]

# %%
data.mfr.value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
data.vitamins.value_counts()
# Out:
# vitamins
# FDA_25     63
# FDA_0       8
# FDA_100     6
# Name: count, dtype: int64

# %%
pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/BD-DM-C02/refs/heads/main/Tabel_Penjualan_Rupiah.csv')
# Out:
#    Transaction ID Tanggal Transaksi Nama Produk    Kategori  Jumlah  \
# 0             101        01-01-2024      Laptop  Elektronik     1.0
# 1             102        02-01-2024  Smartphone  Elektronik     2.0
# 2             103        03-01-2024     Headset    Aksesori     NaN
# 3             104        03-01-2024     Headset    Aksesori     1.0
# 4             105        07-01-2024       Mouse    Aksesori     3.0
# 5             106        04-01-2024    Keyboard    Aksesori     2.0
# 6             107        05-01-2024     Monitor  Elektronik     1.0
# 7             107        05-01-2024     Monitor  Elektronik     1.0
# 8             108        06-01-2024     Printer  Elektronik     NaN
# 9             109        07-01-2024      Tablet  Elektronik     1.0
#
#   Harga (Rupiah) Total Harga (Rupiah)
# 0     15,000,000          15,000,000
# 1     12,000,000          24,000,000
# 2       750,000                   NaN
# 3       750,000              750,000
# ...

# %%
produk = pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/BD-DM-C02/refs/heads/main/Tabel_Penjualan_Rupiah.csv')

# %%
produk.describe()
# Out:
#        Transaction ID    Jumlah
# count        10.00000  8.000000
# mean        105.20000  1.500000
# std           2.65832  0.755929
# min         101.00000  1.000000
# 25%         103.25000  1.000000
# 50%         105.50000  1.000000
# 75%         107.00000  2.000000
# max         109.00000  3.000000
